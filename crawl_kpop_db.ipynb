# %%
import requests
import re
import concurrent.futures
from tqdm import tqdm
import csv
import pandas as pd
from pandas.io.json import json_normalize
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[59], line 7
#       5 import csv
#       6 import pandas as pd
# ----> 7 from pandas.io.json import json_normalize
#
# ImportError: cannot import name 'json_normalize' from 'pandas.io.json' (d:\APP\laragon\bin\python\python-3.10\lib\site-packages\pandas\io\json\__init__.py)

# %%
url = "https://dbkpop.com/wp-admin/admin-ajax.php?action=get_wdtable&table_id=9"
headers = {
    "Cookie": "ezoictest=stable; ezoab_438994=mod293-c; ezoadgid_438994=-1; ezosuibasgeneris-1=45345459-7fb2-410e-6882-bc37b4dae516; lp_438994=https://dbkpop.com/db/k-pop-music-videos/; ezovuuid_438994=a2be30b6-dbb8-43ca-725e-8905efc71201; ezoref_438994=; ezds=ffid%3D1%2Cw%3D1536%2Ch%3D864; _gid=GA1.2.1097409312.1716270184; _sharedid=4cb79eec-c572-416c-b742-3e3efd5f2115; _sharedid_cst=zix7LPQsHA%3D%3D; __gads=ID=9e1ff9b92896831d:T=1716270185:RT=1716270185:S=ALNI_Ma4hu0XiLpZZPLEtV9d2ZYOZpNAoA; __gpi=UID=00000e25fe4fb6a4:T=1716270185:RT=1716270185:S=ALNI_MYv24ZVpnjeFoIfIri6KrTCV8bMlQ; __eoi=ID=589908ce02781ed0:T=1716270185:RT=1716270185:S=AA-AfjYCUs9rwUZwPe8WPrJLYr0x; panoramaId_expiry=1716356590049; _cc_id=2a6b6631ff372911457e9a7667dad4e1; pbjs-unifiedid=%7B%22TDID%22%3A%22c881a5ea-a9c8-4d84-8001-a6a7b46c2db1%22%2C%22TDID_LOOKUP%22%3A%22FALSE%22%2C%22TDID_CREATED_AT%22%3A%222024-05-21T05%3A43%3A10%22%7D; pbjs-unifiedid_cst=zix7LPQsHA%3D%3D; advanced_ads_visitor=%7B%22browser_width%22%3A1519%7D; __qca=P0-1710418674-1716270198191; ezux_ifep_438994=true; active_template::438994=pub_site.1716270207; ezopvc_438994=2; ezovuuidtime_438994=1716270210; ezohw=w%3D1536%2Ch%3D738; _ga_8V1WJRLWL7=GS1.1.1716270185.1.1.1716270211.34.0.0; _ga=GA1.1.945004535.1716270184; advanced_ads_pro_visitor_referrer=%7B%22expires%22%3A1747806219%2C%22data%22%3A%22https%3A%2F%2Fdbkpop.com%2Fdb%2Fk-pop-music-videos%2F%3Ffbclid%3DIwAR0kaZAaJaDUYNSvEeiNjsDH_ZMLdT51P5p5Iw_J8bw7QC_1ZzOfbLQrcHU%22%7D; advanced_ads_page_impressions=%7B%22expires%22%3A2031630195%2C%22data%22%3A2%7D; PHPSESSID=rcvbk3h166irfk1s6fhes9vfsu; ezoawesome_438994=dbkpop_com-medrectangle-2/2024-05-21/581731070049424 1716270339304; _gat=1; ezux_et_438994=25; ezux_tos_438994=145",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.6367.118 Safari/537.36",
    "Referer": "https://dbkpop.com/db/k-pop-music-videos/",
}
data = {
    "draw": "2",
    "columns[0][data]": "0",
    "columns[0][name]": "mvpage",
    "columns[0][searchable]": "true",
    "columns[0][orderable]": "true",
    "columns[0][search][value]": "",
    "columns[0][search][regex]": "false",
    "columns[2][data]": "2",
    "columns[2][name]": "artist",
    "columns[2][searchable]": "true",
    "columns[2][orderable]": "true",
    "columns[2][search][value]": "",
    "columns[2][search][regex]": "false",
    "columns[3][data]": "3",
    "columns[3][name]": "song",
    "columns[3][searchable]": "true",
    "columns[3][orderable]": "true",
    "columns[3][search][value]": "",
    "columns[3][search][regex]": "false",
    "columns[4][data]": "4",
    "columns[4][name]": "hangul",
    "columns[4][searchable]": "true",
    "columns[4][orderable]": "true",
    "columns[4][search][value]": "",
    "columns[4][search][regex]": "false",
    "columns[5][data]": "5",
    "columns[5][name]": "director",
    "columns[5][searchable]": "true",
    "columns[5][orderable]": "true",
    "columns[5][search][value]": "",
    "columns[5][search][regex]": "false",
    "columns[6][data]": "6",
    "columns[6][name]": "videourl",
    "columns[6][searchable]": "true",
    "columns[6][orderable]": "true",
    "columns[6][search][value]": "",
    "columns[6][search][regex]": "false",
    "columns[7][data]": "7",
    "columns[7][name]": "groupt",
    "columns[7][searchable]": "true",
    "columns[7][orderable]": "true",
    "columns[7][search][value]": "",
    "columns[7][search][regex]": "false",
    "columns[8][data]": "8",
    "columns[8][name]": "reltype",
    "columns[8][searchable]": "true",
    "columns[8][orderable]": "true",
    "columns[8][search][value]": "",
    "columns[8][search][regex]": "false",
    "order[0][column]": "1",
    "order[0][dir]": "desc",
    "start": "0",
    "length": "-1",
    "search[value]": "",
    "search[regex]": "false",
    "wdtNonce": "aabf9cd1f4",
    "sRangeSeparator": "|",
}

# %%
response = requests.post(url, headers=headers, data=data)
data = response.json()
print(data)
# Out:
# {'draw': 2, 'recordsTotal': '5596', 'recordsFiltered': '5596', 'data': [['', '2024-12-30', 'tripleS', 'Just Do It (NXT)', '', '', '<a href="https://youtu.be/s3IfM-u5hVc">Youtube</a>', 'Girl', 'Major'], ['', '2024-05-10', 'Stray Kids', 'Lose My Breath feat. Charlie Puth', '', '', '<a href="https://youtu.be/SQ1yPMTIwCU">Youtube</a>', 'Boy', 'Minor'], ['', '2024-05-10', 'RM', 'Come back to me', '', '', '<a href="https://youtu.be/NrfikKxF4Ps">Youtube</a>', 'Boy Solo', 'Major'], ['', '2024-05-10', 'ARTMS', 'Pre4 : Air', '', '', '<a href="https://youtu.be/ZSkzF0ucsLI">Youtube</a>', 'Girl', 'Minor'], ['', '2024-05-09', 'Seventeen', 'LALALI', '', '', '<a href="https://youtu.be/F2qZWD0F7rM">Youtube</a>', 'Boy', 'Major'], ['', '2024-05-09', 'Loossemble', "Girls' Night", '', '', '<a href="https://youtu.be/yrG5NfrAr_g">Youtube</a>', 'Girl', 'Minor'], ['', '2024-05-09', 'Yook Sungjae', 'Be Somebody', '', '', '<a href="https://youtu.be/TsfAFHeNDXk">Youtube</a>', 'Boy Solo', 'Major'], ['', '2024-05
# ...

# %%
len = int(data['recordsTotal'])
songs = []
for i in range(len):
    song = {}
    song['db'] = {}
    song['db']['pubDate'] = data['data'][i][1]
    song['db']['artist'] = data['data'][i][2]
    song['db']['song_name'] = data['data'][i][3]
    yturl = data['data'][i][6]
    match = re.search('href="([^"]*)', yturl)
    if match:
        song['db']['yturl'] = match.group(1)
    else:
        song['db']['yturl'] = ''
    song['db']['type'] = data['data'][i][7]
    song['db']['release'] = data['data'][i][8]
    songs.append(song)
print(songs)
# Out:
# [{'db': {'pubDate': '2024-12-30', 'artist': 'tripleS', 'song_name': 'Just Do It (NXT)', 'yturl': 'https://youtu.be/s3IfM-u5hVc', 'type': 'Girl', 'release': 'Major'}}, {'db': {'pubDate': '2024-05-10', 'artist': 'Stray Kids', 'song_name': 'Lose My Breath feat. Charlie Puth', 'yturl': 'https://youtu.be/SQ1yPMTIwCU', 'type': 'Boy', 'release': 'Minor'}}, {'db': {'pubDate': '2024-05-10', 'artist': 'RM', 'song_name': 'Come back to me', 'yturl': 'https://youtu.be/NrfikKxF4Ps', 'type': 'Boy Solo', 'release': 'Major'}}, {'db': {'pubDate': '2024-05-10', 'artist': 'ARTMS', 'song_name': 'Pre4 : Air', 'yturl': 'https://youtu.be/ZSkzF0ucsLI', 'type': 'Girl', 'release': 'Minor'}}, {'db': {'pubDate': '2024-05-09', 'artist': 'Seventeen', 'song_name': 'LALALI', 'yturl': 'https://youtu.be/F2qZWD0F7rM', 'type': 'Boy', 'release': 'Major'}}, {'db': {'pubDate': '2024-05-09', 'artist': 'Loossemble', 'song_name': "Girls' Night", 'yturl': 'https://youtu.be/yrG5NfrAr_g', 'type': 'Girl', 'release': 'Minor'}}, {'
# ...

# %%
headers = {
    'Authorization': "Bearer BQDeClxvJHuimhNKZpBVLSK5ym30gjQpwZI38Ndtwxw_W-YvzubkdG54A7rp5lJGmK_ZWTceATRBGiGY1iuhGvfhLR4AWc1y6syRBRE4k6ne5P18cRunsBUvpS2d7CHckymjnz3wlcRUlud6ajXXSXWtiiKgIJ4--Lujg86rJQ0Y5QeYELLTO7SH04thbm0i39DD3RVlCmmdBmp6fR8sqUQ_DAatN4j_ZXaTHu7zvDiZacSfTq-wyqolKEt7GDfk5BG_zsJov6haIbNpHoUohX5n4RkB0YAP5da11PQaHAZGZr7LsYXHThQbxa2nx6oTNWWEdsUjLtIS0DztSE1CbrAC-hFU"
}
def fetch_spotify_details(i):
    song_name = songs[i]['db']['song_name'].replace(' ', '%20')
    artist = songs[i]['db']['artist'].replace(' ', '%20')
    url = "https://api.spotify.com/v1/search?q={}%20{}&type=track&limit=1".format(song_name, artist)
    response = requests.get(url, headers=headers)
    data = response.json()
    spotify_details = {}

    try:
        spotify_details['track'] = {}
        spotify_details['track']['id'] = data['tracks']['items'][0]['id']
        spotify_details['track']['href'] = data['tracks']['items'][0]['href']
        spotify_details['track']['name'] = data['tracks']['items'][0]['name']
        spotify_details['track']['popularity'] = data['tracks']['items'][0]['popularity']
        spotify_details['track']['duration_ms'] = data['tracks']['items'][0]['duration_ms']
        spotify_details['track']['track_number'] = data['tracks']['items'][0]['track_number']

        spotify_details['album'] = {}
        spotify_details['album']['id'] = data['tracks']['items'][0]['album']['id']
        spotify_details['album']['name'] = data['tracks']['items'][0]['album']['name']
        spotify_details['album']['type'] = data['tracks']['items'][0]['album']['album_type']
        spotify_details['album']['release_date'] = data['tracks']['items'][0]['album']['release_date']
        spotify_details['album']['total_tracks'] = data['tracks']['items'][0]['album']['total_tracks']
        spotify_details['album']['href'] = data['tracks']['items'][0]['album']['href']

        spotify_details['artist'] = {}
        spotify_details['artist']['id'] = data['tracks']['items'][0]['artists'][0]['id']
        spotify_details['artist']['name'] = data['tracks']['items'][0]['artists'][0]['name']
        spotify_details['artist']['href'] = data['tracks']['items'][0]['artists'][0]['href']

        response = requests.get(spotify_details['album']['href'], headers=headers)
        spotify_details['album']['popularity'] = response.json()['popularity']
        spotify_details['album']['genres'] = ', '.join(response.json()['genres'])

        response = requests.get(spotify_details['artist']['href'], headers=headers)
        spotify_details['artist']['popularity'] = response.json()['popularity']
        spotify_details['artist']['followers'] = response.json()['followers']['total']
        spotify_details['artist']['genres'] = ', '.join(response.json()['genres'])
    except Exception as e:
        spotify_details = {}
        return False
    finally:
        songs[i]['spotify'] = spotify_details
        
failed_crawls = 0
with concurrent.futures.ThreadPoolExecutor() as executor:
    results = list(tqdm(executor.map(fetch_spotify_details, range(len)), total=len))

failed_crawls = results.count(False)
print(f"Number of failed crawls: {failed_crawls}")
# Out:
# 100%|██████████| 5596/5596 [04:55<00:00, 18.96it/s]
# Number of failed crawls: 11

# %%
flattened_songs = pd.json_normalize(songs)
flattened_songs.to_csv('songs_new.csv', index=False)

# %%
songs_df = pd.read_csv('songs_new.csv')
songs_df
# Out:
#       db.pubDate           db.artist                       db.song_name  \
# 0     2024-12-30             tripleS                   Just Do It (NXT)
# 1     2024-05-10          Stray Kids  Lose My Breath feat. Charlie Puth
# 2     2024-05-10                  RM                    Come back to me
# 3     2024-05-10               ARTMS                         Pre4 : Air
# 4     2024-05-09           Seventeen                             LALALI
# ...          ...                 ...                                ...
# 5591  1994-08-08  Seo Taiji and Boys                           Eternity
# 5592  1993-06-06  Seo Taiji and Boys                        Anyhow Song
# 5593  1993-06-06  Seo Taiji and Boys                             To You
# 5594  1992-03-23  Seo Taiji and Boys                             I Know
# 5595  1992-03-23  Seo Taiji and Boys                You, In The Fantasy
#
#                           db.yturl   db.type db.release  \
# ...
